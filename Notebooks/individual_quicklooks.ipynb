# %%
import giants as g
import lightkurve as lk
import matplotlib.pyplot as plt
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
tics = [80085967, 89020549, 97408875]
# tics = [139149525]
for tic in tics:
    try:
        target = g.Giant()
        target.plot(ticid=f'TIC {tic}')
        target.plot_starry_model()
    except:
        print(f"{tic} failed.")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2910: DtypeWarning: Columns (85,115) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Creating light curve for target 80085967 for sectors [1].
# ...
# Inflating...
# 100%|██████████| 1282/1282 [00:17<00:00, 73.44it/s]
# optimizing logp for variables: ['t0', 'period_interval__']
# message: Desired error not necessarily achieved due to precision loss.
# logp: -1219366.774204931 -> -1196398.2161552655
# optimizing logp for variables: ['mean', 'r_pl_interval__']
# message: Desired error not necessarily achieved due to precision loss.
# logp: -1196398.2161552648 -> -1181301.159590544
# optimizing logp for variables: ['mean', 't0', 'period_interval__']
# message: Desired error not necessarily achieved due to precision loss.
# logp: -1181301.1595905435 -> -1181275.5484043383
# optimizing logp for variables: ['mean', 'r_pl_interval__']
# ...

# %%
target = g.Giant()
target.plot(ticid='TIC 5632182', lc_source='eleanor')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2910: DtypeWarning: Columns (85,115) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Creating light curve for target 5632182 for sectors [2].
# 100%|██████████| 1245/1245 [00:14<00:00, 83.71it/s]

# %%
target.plot_starry_model()

# %% [markdown]
# # Targets to follow up:
#  - 47316976
