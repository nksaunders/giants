# %%
import giants as gs

# %%
giant = gs.Giant()
# Out:
# Using the brightest 727 targets.

# %%
for i in range(23):
    try:
        lcc = giant.get_lightcurve(ind=i, pld=True)
        giant.plot(lcc=lcc, use='pld')
    except:
        print(f'index {i} failed')
        continue
# Out:
# 389689344
# WARNING: AstropyDeprecationWarning: Importing BoxLeastSquares from astropy.stats has been deprecated and will no longer be supported in future. Please import this class from the astropy.timeseries module instead [astropy.stats.bls]
# 197682684
# WARNING: AstropyDeprecationWarning: Importing BoxLeastSquares from astropy.stats has been deprecated and will no longer be supported in future. Please import this class from the astropy.timeseries module instead [astropy.stats.bls]
# 160527775
# ...
# /Users/nksaunders/Documents/Github/lightkurve/lightkurve/lightcurve.py:654: LightkurveWarning: The light curve appears to be zero-centered; `normalize()` will divide the light curve by zero or a value close to zero. (median_flux=0.00e+00, std_flux=0.00e+00).
#   LightkurveWarning)
# /Users/nksaunders/Documents/Github/lightkurve/lightkurve/lightcurve.py:665: RuntimeWarning: invalid value encountered in true_divide
#   lc.flux = lc.flux / median_flux
# ...
