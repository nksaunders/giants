# %%
import giants as gs

# %%
g = gs.Giant()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2910: DtypeWarning: Columns (85,115) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
tics = g.get_target_list()

# %%
for tic in tics[200:]:
    try:
        g.plot(ticid=tic)
    except:
        print(f'TIC {tic} failed.')
# Out:
# Creating light curve for target 261542304 for sectors [1, 13].
# ...
# 100%|██████████| 1320/1320 [00:17<00:00, 74.53it/s]
# /anaconda3/lib/python3.6/site-packages/matplotlib/scale.py:111: RuntimeWarning: invalid value encountered in less_equal
#   out[a <= 0] = -1000
# Creating light curve for target 261542399 for sectors [1, 13].
# ...
# 100%|██████████| 1320/1320 [00:17<00:00, 75.96it/s]
# /anaconda3/lib/python3.6/site-packages/matplotlib/scale.py:111: RuntimeWarning: invalid value encountered in less_equal
#   out[a <= 0] = -1000
# Creating light curve for target 261542520 for sectors [1, 13].
# ...
# 100%|██████████| 1320/1320 [00:15<00:00, 86.31it/s]
# /anaconda3/lib/python3.6/site-packages/matplotlib/scale.py:111: RuntimeWarning: invalid value encountered in less_equal
#   out[a <= 0] = -1000
# Creating light curve for target 261542579 for sectors [1, 13].
# ...
# 100%|██████████| 1320/1320 [00:16<00:00, 80.41it/s]
# ...
